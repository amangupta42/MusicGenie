# %%
# !pip install -r requirements.txt
# Out:
# Collecting gensim==4.2.0
#   Downloading gensim-4.2.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 6.0 MB/s eta 0:00:01
# Collecting gevent==21.12.0
#   Downloading gevent-21.12.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 85.7 MB/s eta 0:00:01
# Collecting keybert==0.5.1
#   Downloading keybert-0.5.1.tar.gz (19 kB)
# Collecting nltk==3.7
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 24.4 MB/s eta 0:00:01
# Collecting numpy==1.23.0
#   Downloading numpy-1.23.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 24.5 MB/s eta 0:00:01                     | 1.8 MB 24.5 MB/s eta 0:00:01[K     |███████▎                        | 3.9 MB 24.5 MB/s eta 0:00:01��█▎                | 8.1 MB 24.5 MB/s eta 0:00:01�██▍        | 12.4 MB 24.5 MB/s eta 0:00:01
# Collecting pandas==1.4.1
#   Downloading pandas-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 86.8 MB/s eta 0:00:01�██████████████████      | 9.5 MB 86.8 MB/s eta 0:00:01
# Collecting requests==2.27.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.1 MB/s  eta 0:00:01
# Requirement already satisfied: sentence_transformers==2.2.2 in ./.conda/envs/default/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (2.2.2)
# Collecting spacy==3.3.1
#   Downloading spacy-3.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 14.6 MB/s eta 0:00:01
# Collecting spotipy==2.20.0
#   Downloading spotipy-2.20.0-py3-none-any.whl (27 kB)
# Collecting torch==1.12.0
#   Downloading torch-1.12.0-cp39-cp39-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 5.6 kB/s  eta 0:00:014B 12.0 MB/s eta 0:01:030201     |██▍                             | 57.0 MB 12.0 MB/s eta 0:01:00     |███▋                            | 88.1 MB 17.2 MB/s eta 0:00:40��                           | 100.9 MB 58.3 MB/s eta 0:00:12MB/s eta 0:00:12     |█████                           | 120.6 MB 58.3 MB/s eta 0:00:12         | 142.1 MB 2.0 MB/s eta 0:05:21MB 11.3 MB/s eta 0:00:54��███▎                        | 177.5 MB 11.3 MB/s eta 0:00:53MB 26.7 MB/s eta 0:00:22MB 26.7 MB/s eta 0:00:22|██████████▋                     | 257.4 MB 2.7 MB/s eta 0:03:13�████████▊                     | 260.0 MB 2.7 MB/s eta 0:03:12/s eta 0:06:27     |████████████▋                   | 305.4 MB 90.8 MB/s eta 0:00:06        | 341.8 MB 17.0 MB/s eta 0:00:26�█████████▏                 | 343.1 MB 17.0 MB/s eta 0:00:26�█▍                 | 348.9 MB 24.4 MB/s eta 0:00:18| 354.6 MB 24.4 MB/s eta 0:00:18     |████████████████▊               | 405.6 MB 103.2 MB/s eta 0:00:04  | 414.3 MB 2.2 MB/s eta 0:02:44��███████▏              | 417.0 MB 2.2 MB/s eta 0:02:43     |█████████████████▌              | 424.3 MB 2.2 MB/s eta 0:02:40��███████▊              | 429.7 MB 2.2 MB/s eta 0:02:37��████████              | 438.6 MB 2.2 MB/s eta 0:02:33     |██████████████████▎             | 444.5 MB 2.1 MB/s eta 0:02:39 |██████████████████▉             | 456.3 MB 2.1 MB/s eta 0:02:34     |███████████████████▏            | 466.2 MB 1.4 MB/s eta 0:03:40    | 483.4 MB 1.4 MB/s eta 0:03:27�████████▏           | 489.2 MB 7.7 MB/s eta 0:00:38�████████▋           | 499.8 MB 7.7 MB/s eta 0:00:36�█████████           | 507.4 MB 7.7 MB/s eta 0:00:36�█████████           | 512.0 MB 7.7 MB/s eta 0:00:35     |█████████████████████▍          | 517.6 MB 10.5 MB/s eta 0:00:25:00:25        | 542.6 MB 17.6 MB/s eta 0:00:14        | 558.5 MB 17.6 MB/s eta 0:00:13�██████████▌        | 570.1 MB 17.6 MB/s eta 0:00:12�▉        | 577.6 MB 8.5 MB/s eta 0:00:24██████        | 582.2 MB 8.5 MB/s eta 0:00:236.7 MB 8.5 MB/s eta 0:00:23     |█████████████████████████▋      | 621.3 MB 1.9 MB/s eta 0:01:24 | 634.0 MB 1.9 MB/s eta 0:01:17 | 655.9 MB 2.2 MB/s eta 0:00:55�████████▏    | 659.7 MB 2.2 MB/s eta 0:00:53��████████████████████████▏   | 682.9 MB 13.1 MB/s eta 0:00:08██████████████████▋   | 694.1 MB 13.0 MB/s eta 0:00:07��█████████████████████████   | 705.2 MB 13.0 MB/s eta 0:00:06ta 0:00:05�█████████▊ | 744.4 MB 10.7 MB/s eta 0:00:0301
# Collecting xgboost==1.6.1
#   Downloading xgboost-1.6.1-py3-none-manylinux2014_x86_64.whl (192.9 MB)
#      |████████████████████████████████| 192.9 MB 75 kB/s  eta 0:00:0101  |▋                               | 3.9 MB 61.4 MB/s eta 0:00:04 MB 61.4 MB/s eta 0:00:03               | 60.4 MB 12.2 MB/s eta 0:00:112.2 MB/s eta 0:00:10  | 99.0 MB 12.2 MB/s eta 0:00:08[K     |██████████████████              | 108.1 MB 129.1 MB/s eta 0:00:01    |███████████████████████▎        | 140.2 MB 129.1 MB/s eta 0:00:01 | 158.5 MB 7.6 MB/s eta 0:00:05 | 161.0 MB 7.6 MB/s eta 0:00:05     |████████████████████████████    | 168.5 MB 7.6 MB/s eta 0:00:04��███████████████████▏   | 170.1 MB 7.6 MB/s eta 0:00:03    |█████████████████████████████▍  | 176.8 MB 7.6 MB/s eta 0:00:03    |█████████████████████████████▉  | 179.5 MB 7.6 MB/s eta 0:00:021 MB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.18.1 in ./.conda/envs/default/lib/python3.9/site-packages (from gensim==4.2.0->-r requirements.txt (line 1)) (1.9.3)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.4 MB/s eta 0:00:011
# Requirement already satisfied: setuptools in ./.conda/envs/default/lib/python3.9/site-packages (from gevent==21.12.0->-r requirements.txt (line 2)) (65.5.1)
# Collecting zope.interface
#   Downloading zope.interface-5.5.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (257 kB)
#      |████████████████████████████████| 257 kB 16.3 MB/s eta 0:00:01
# Collecting greenlet<2.0,>=1.1.0
#   Downloading greenlet-1.1.3.post0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (154 kB)
#      |████████████████████████████████| 154 kB 23.3 MB/s eta 0:00:01
# Collecting zope.event
#   Downloading zope.event-4.6-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: scikit-learn>=0.22.2 in ./.conda/envs/default/lib/python3.9/site-packages (from keybert==0.5.1->-r requirements.txt (line 3)) (1.1.3)
# Collecting rich>=10.4.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 53.6 MB/s eta 0:00:01
# Requirement already satisfied: joblib in ./.conda/envs/default/lib/python3.9/site-packages (from nltk==3.7->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: click in ./.conda/envs/default/lib/python3.9/site-packages (from nltk==3.7->-r requirements.txt (line 4)) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in ./.conda/envs/default/lib/python3.9/site-packages (from nltk==3.7->-r requirements.txt (line 4)) (2022.10.31)
# Requirement already satisfied: tqdm in ./.conda/envs/default/lib/python3.9/site-packages (from nltk==3.7->-r requirements.txt (line 4)) (4.64.1)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/envs/default/lib/python3.9/site-packages (from pandas==1.4.1->-r requirements.txt (line 6)) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./.conda/envs/default/lib/python3.9/site-packages (from pandas==1.4.1->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.conda/envs/default/lib/python3.9/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (3.4)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in ./.conda/envs/default/lib/python3.9/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.conda/envs/default/lib/python3.9/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (1.26.12)
# Requirement already satisfied: huggingface-hub>=0.4.0 in ./.conda/envs/default/lib/python3.9/site-packages (from sentence_transformers==2.2.2->-r requirements.txt (line 8)) (0.11.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in ./.conda/envs/default/lib/python3.9/site-packages (from sentence_transformers==2.2.2->-r requirements.txt (line 8)) (4.25.1)
# Requirement already satisfied: torchvision in ./.conda/envs/default/lib/python3.9/site-packages (from sentence_transformers==2.2.2->-r requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: sentencepiece in ./.conda/envs/default/lib/python3.9/site-packages (from sentence_transformers==2.2.2->-r requirements.txt (line 8)) (0.1.97)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (668 kB)
#      |████████████████████████████████| 668 kB 24.6 MB/s eta 0:00:01
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (490 kB)
#      |████████████████████████████████| 490 kB 44.2 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in ./.conda/envs/default/lib/python3.9/site-packages (from spacy==3.3.1->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/default/lib/python3.9/site-packages (from spacy==3.3.1->-r requirements.txt (line 9)) (21.3)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.9-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 65.0 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 1.6 MB/s eta 0:00:011
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp39-cp39-manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 110.7 MB/s eta 0:00:01        | 931 kB 110.7 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#      |████████████████████████████████| 128 kB 83.2 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 8.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.15.0 in ./.conda/envs/default/lib/python3.9/site-packages (from spotipy==2.20.0->-r requirements.txt (line 10)) (1.16.0)
# Collecting redis>=3.5.3
#   Downloading redis-4.4.0-py3-none-any.whl (236 kB)
#      |████████████████████████████████| 236 kB 15.5 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in ./.conda/envs/default/lib/python3.9/site-packages (from torch==1.12.0->-r requirements.txt (line 11)) (4.4.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: filelock in ./.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers==2.2.2->-r requirements.txt (line 8)) (3.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./.conda/envs/default/lib/python3.9/site-packages (from packaging>=20.0->spacy==3.3.1->-r requirements.txt (line 9)) (3.0.9)
# Requirement already satisfied: async-timeout>=4.0.2 in ./.conda/envs/default/lib/python3.9/site-packages (from redis>=3.5.3->spotipy==2.20.0->-r requirements.txt (line 10)) (4.0.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 11.7 MB/s eta 0:00:01
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in ./.conda/envs/default/lib/python3.9/site-packages (from rich>=10.4.0->keybert==0.5.1->-r requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.conda/envs/default/lib/python3.9/site-packages (from scikit-learn>=0.22.2->keybert==0.5.1->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./.conda/envs/default/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers==2.2.2->-r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/default/lib/python3.9/site-packages (from jinja2->spacy==3.3.1->-r requirements.txt (line 9)) (2.1.1)
# Collecting torchvision
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 77.5 MB/s eta 0:00:01    |████████████████                | 12.1 MB 77.5 MB/s eta 0:00:01
#   Downloading torchvision-0.13.1-cp39-cp39-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 25.0 MB/s eta 0:00:01
#   Downloading torchvision-0.13.0-cp39-cp39-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 52.1 MB/s eta 0:00:01�███▌             | 11.0 MB 52.1 MB/s eta 0:00:01
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./.conda/envs/default/lib/python3.9/site-packages (from torchvision->sentence_transformers==2.2.2->-r requirements.txt (line 8)) (9.3.0)
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.1-py3-none-any.whl size=21310 sha256=8fc94ee05fbc124709c8ffe1cdb4ebcbf9d8d9512497f46ef71902a7f33aad7b
#   Stored in directory: /home/studio-lab-user/.cache/pip/wheels/94/18/2a/f26bbcd25924aab452bb4bcc2345a55c07160823d196a264c7
# Successfully built keybert
# WARNING: Error parsing requirements for wordcloud: [Errno 2] No such file or directory: '/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/wordcloud-1.8.2.2.dist-info/METADATA'
# Installing collected packages: charset-normalizer, requests, numpy, torch, murmurhash, cymem, catalogue, wasabi, typer, torchvision, srsly, smart-open, pydantic, preshed, nltk, commonmark, blis, zope.interface, zope.event, thinc, spacy-loggers, spacy-legacy, rich, redis, pathy, langcodes, greenlet, xgboost, spotipy, spacy, pandas, keybert, gevent, gensim
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.1.1
#     Uninstalling charset-normalizer-2.1.1:
#       Successfully uninstalled charset-normalizer-2.1.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0
#     Uninstalling torch-1.13.0:
#       Successfully uninstalled torch-1.13.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0
#     Uninstalling torchvision-0.14.0:
#       Successfully uninstalled torchvision-0.14.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8
#     Uninstalling nltk-3.8:
#       Successfully uninstalled nltk-3.8
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 1.7.2
#     Uninstalling xgboost-1.7.2:
#       Successfully uninstalled xgboost-1.7.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.2
#     Uninstalling pandas-1.5.2:
#       Successfully uninstalled pandas-1.5.2
# Successfully installed blis-0.7.9 catalogue-2.0.8 charset-normalizer-2.0.12 commonmark-0.9.1 cymem-2.0.7 gensim-4.2.0 gevent-21.12.0 greenlet-1.1.3.post0 keybert-0.5.1 langcodes-3.3.0 murmurhash-1.0.9 nltk-3.7 numpy-1.23.0 pandas-1.4.1 pathy-0.10.1 preshed-3.0.8 pydantic-1.8.2 redis-4.4.0 requests-2.27.1 rich-12.6.0 smart-open-6.3.0 spacy-3.3.1 spacy-legacy-3.0.10 spacy-loggers-1.0.4 spotipy-2.20.0 srsly-2.4.5 thinc-8.0.17 torch-1.12.0 torchvision-0.13.0 typer-0.4.2 wasabi-0.10.1 xgboost-1.6.1 zope.event-4.6 zope.interface-5.5.2

# %%
import pandas as pd
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_158/3626439972.py in <cell line: 7>()
#       5 import matplotlib.pyplot as plt
#       6 from tqdm.notebook import tqdm
# ----> 7 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# ## Creating dataframe from raw data.

# %%
#Defining functions for opening the json files and converting them into dataframes.
def get_json(file):
    
    f = open(file)
    data = json.load(f)
    return data

# %%
#Store the file location of each slice of data.
json_location_list=os.listdir('./data/')
json_location_list=["./data/"+ location for location in json_location_list]

# %%
#This stores all json file data
jsons=[get_json(i) for i in json_location_list[:10]]

# %%
# Convert json files to data frames.
def get_dataframes(json_file):
    # Calling the first JSON file and viewing the object
    js1_items = json_file.items()
    # Turning the items from the first JSON file into a list
    js1_list = list(js1_items)
    # Creating a DataFrame from the list
    return pd.DataFrame(js1_list)

# %%
#All jsons have an individual dataframe stored in a list.
dfs = [get_dataframes(i) for i in jsons]

# %%
dfs[1].head()
# Out:
#            0                                                  1
# 0       info  {'generated_on': '2017-12-03 08:41:42.057563',...
# 1  playlists  [{'name': 'disney', 'collaborative': 'false', ...

# %% [markdown]
# We can see that the dataframe is not yet usable. We need to make a clean dataframe.

# %%
#Store the nested elements of the frame
testr = []
countdf = 0
countitem = 0
for i in dfs:
    countdf += 1
    for j in i[1]:
        countitem+=1
        testr.append(j)

# %%
testr=[testr[i] for i in range(1,20,2)]

# %%
len(testr)
# Out:
# 10

# %%
testr[0][:1]

# %%
#Creating the dataframe for songs.
df=pd.DataFrame()
def create_df(var):    
    global df
    songs=pd.json_normalize(var,record_path=['tracks'])
    df = pd.concat([df,songs], axis=0)

# %%
for i in range(10):
    create_df(testr[i])

# %%
df.size
# Out:
# 5335672

# %%
songs = df

# %%
songs.tail()
# Out:
#         pid  pos   artist_name                             track_uri  \
# 64934  9999  161      Mc Magic  spotify:track:2ovm5VZJ36s3HKF8nkcIZI
# 64935  9999  162      Mc Magic  spotify:track:2IqCOKEx7mzSp4BTxkdFIV
# 64936  9999  163   Céline Dion  spotify:track:4Dw02sVUfUA67l3fZ9FoKs
# 64937  9999  164   Céline Dion  spotify:track:4qhkS0lRL2GgDxpuIr2Mbb
# 64938  9999  165  Amanda Perez  spotify:track:2FQ5y4bYmq2h974oUBxoZH
#
#                                   artist_uri  \
# 64934  spotify:artist:3cuVSUrq0yoSSP7gpvI6q1
# 64935  spotify:artist:3cuVSUrq0yoSSP7gpvI6q1
# 64936  spotify:artist:4S9EykWXhStSc15wEx8QFK
# 64937  spotify:artist:4S9EykWXhStSc15wEx8QFK
# 64938  spotify:artist:5DqmNLPM1kAbSBQk2FMm6b
#
#                                               track_name  \
# 64934                                          Sexy Lady
# 64935                                        Be With You
# 64936    My Heart Will Go On - Love Theme from "Titanic"
# 64937  Because You Loved Me (Theme from "Up Close and...
# 64938                                            Goodbye
#
#                                   album_uri  duration_ms  \
# 64934  spotify:album:7BlkHZxgF2tX7lk12c3DOa       234840
# 64935  spotify:album:7BlkHZxgF2tX7lk12c3DOa       250093
# 64936  spotify:album:05HEjdd9s8Egs5aa3r0YIF       280133
# 64937  spotify:album:05HEjdd9s8Egs5aa3r0YIF       273026
# 64938  spotify:album:6flBGbh4DeR2edxBff0WbO       250186
#
#                             album_name
# 64934                       MAGIC CITY
# 64935                       MAGIC CITY
# 64936  All The Way... A Decade Of Song
# 64937  All The Way... A Decade Of Song
# 64938                 The Hand Of Fate

# %%
playlists = pd.DataFrame()
def create_p_df(var):
    global playlists
    playlist = pd.json_normalize(var)
    playlists = pd.concat([playlist,playlists], axis=0)

# %%
for i in range(10):
    create_p_df(testr[i])

# %%
playlists.head()
# Out:
#              name collaborative    pid  modified_at  num_tracks  num_albums  \
# 0           Happy         false  11000   1479945600          46          42
# 1  Crowd Pleasers         false  11001   1485561600          62          52
# 2            2016         false  11002   1469059200          36          33
# 3       Halloween         false  11003   1509408000          45          32
# 4  random stuff!          false  11004   1487548800          48          44
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'John Mayer', 'trac...
# 1              1  [{'pos': 0, 'artist_name': 'Shaggy', 'track_ur...
# 2              2  [{'pos': 0, 'artist_name': 'Unknown Mortal Orc...
# 3              1  [{'pos': 0, 'artist_name': 'John Carpenter', '...
# 4              2  [{'pos': 0, 'artist_name': 'Petite Noir', 'tra...
#
#    num_edits  duration_ms  num_artists description
# 0         16     10467071           40         NaN
# 1          7     14558428           38         NaN
# 2         16     10609887           30         NaN
# 3          3     11938641           28         NaN
# 4         12     11019277           40         NaN

# %%
playlists = playlists.drop('tracks', axis =1)

# %%
playlists.shape
# Out:
# (10000, 11)

# %%
playlists['pid'] = playlists.index
playlists
# Out:
#                 name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0              Happy         false    0   1479945600          46          42
# 1     Crowd Pleasers         false    1   1485561600          62          52
# 2               2016         false    2   1469059200          36          33
# 3          Halloween         false    3   1509408000          45          32
# 4     random stuff!          false    4   1487548800          48          44
# ..               ...           ...  ...          ...         ...         ...
# 995              old         false  995   1507852800          41          40
# 996             Daze         false  996   1479254400          17          17
# 997              rap         false  997   1410307200         119          98
# 998          Country         false  998   1507939200         108          75
# 999  thinking of you         false  999   1507766400          44          43
#
#      num_followers  num_edits  duration_ms  num_artists description
# 0                1         16     10467071           40         NaN
# 1                1          7     14558428           38         NaN
# 2                2         16     10609887           30         NaN
# 3                1          3     11938641           28         NaN
# 4                2         12     11019277           40         NaN
# ..             ...        ...          ...          ...         ...
# 995              1          8      9917901           36         NaN
# 996              1         13      3699248           15         NaN
# 997              1         63     27538723           82         NaN
# 998              1         37     24950143           40         NaN
# 999              1         34      9065801           37         NaN
#
# [10000 rows x 11 columns]

# %%
pid_column = playlists.pop('pid')

# %%
playlists.insert(loc = 0, column = 'pid' ,value = [i for i in range(10000)])

# %%
playlists.head()
# Out:
#    pid            name collaborative  modified_at  num_tracks  num_albums  \
# 0    0           Happy         false   1479945600          46          42
# 1    1  Crowd Pleasers         false   1485561600          62          52
# 2    2            2016         false   1469059200          36          33
# 3    3       Halloween         false   1509408000          45          32
# 4    4  random stuff!          false   1487548800          48          44
#
#    num_followers  num_edits  duration_ms  num_artists description
# 0              1         16     10467071           40         NaN
# 1              1          7     14558428           38         NaN
# 2              2         16     10609887           30         NaN
# 3              1          3     11938641           28         NaN
# 4              2         12     11019277           40         NaN

# %%
pid_list_for_songs = []
pid=0
for num_tracks in playlists['num_tracks']:
  for i in range(num_tracks):
    pid_list_for_songs.append(pid)
  pid+=1

# %%
songs = songs.insert(loc = 0, column = 'pid' ,value = pid_list_for_songs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_158/325070380.py in <cell line: 1>()
# ----> 1 songs = songs.insert(loc = 0, column = 'pid' ,value = pid_list_for_songs)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4812         if not allow_duplicates and column in self.columns:
#    4813             # Should this be a different kind of error??
# -> 4814             raise ValueError(f"cannot insert {column}, already exists")
#    4815         if not isinstance(loc, int):
#    4816             raise TypeError("loc must be int")
#
# ValueError: cannot insert pid, already exists

# %%
playlists.shape
# Out:
# (10000, 11)

# %%
print(f"{songs.pid.nunique()} playlists in dataset")
# Out:
# 10000 playlists in dataset

# %%
list(playlists.columns), list(songs.columns)
# Out:
# (['pid',
#   'name',
#   'collaborative',
#   'modified_at',
#   'num_tracks',
#   'num_albums',
#   'num_followers',
#   'num_edits',
#   'duration_ms',
#   'num_artists',
#   'description'],
#  ['pid',
#   'pos',
#   'artist_name',
#   'track_uri',
#   'artist_uri',
#   'track_name',
#   'album_uri',
#   'duration_ms',
#   'album_name'])

# %%
print(f"Approximately {songs.shape[0] / playlists.shape[0]:.1f} songs per playlist") # mean playlist length
print(f"Longest playlist: {playlists.num_tracks.max()} songs") # longest playlist
print(f"Shortest playlist: {playlists.num_tracks.min()} songs") # shortest playlist
# Out:
# Approximately 66.7 songs per playlist
# Longest playlist: 250 songs
# Shortest playlist: 5 songs

# %% [markdown]
# ### Important Considerations
#
# #### Overall demographics of users contributing to the MPD
#
# ##### Gender
#  * Male: 45%
#  * Female: 54%
#  * Unspecified: 0.5%
#  * Nonbinary: 0.5%
#
# ##### Age
#  * 13-17:  10%
#  * 18-24:  43%
#  * 25-34:  31%
#  * 35-44:   9%
#  * 45-54:   4%
#  * 55+:     3%
#
# ##### Country
#  * US: 100%
#
# #### Time Created
#
# - ##### "These playlists were created during the period of January 2010 through October 2017."

# %% [markdown]
# ### Helpful Functions & Dicts

# %%
def get_playlist_info(pid):
    return playlists.loc(pid)

def get_playlist(pid):
    return songs[songs['pid'] == pid]

# Dict #1: {pid: playlist_name}
pid_name_df = playlists[['pid', 'name']]
pid_to_name = {pid_name_df['pid'][i]: pid_name_df['name'][i] for i in range(pid_name_df.shape[0])}
del pid_name_df # remove from memory

# Dict #2: {pid: playlist_followers}
pid_followers_df = playlists[['pid', 'num_followers']]
pid_to_followers = {pid_followers_df['pid'][i]: pid_followers_df['num_followers'][i] for i in range(pid_followers_df.shape[0])}
del pid_followers_df # remove from memory

# %% [markdown]
# ### EDA - Feature Analysis

# %%
# separate features for EDA

# (1) Playlists DataFrame
text_p = ['name', 'description']
temporal_p = ['modified_at'] # in 'seconds since last epoch' (playlists created btw 2010 and 2017)
num_dis_p = ['pid', 'num_edits', 'num_artists', 'num_tracks', 'num_albums', 'num_followers']
num_cont_p = ['duration_ms']
cat_nom_p = ['collaborative']

# (2) Songs DataFrame
test_s = ['track_name', 'artist_name', 'album_name']
num_dis_s = ['pid', 'playlist_pos']
spotify_codes = ['track_uri', 'artist_uri', 'album_uri']

# %% [markdown]
# #### Playlist 'Last Modification' Date

# %%
playlists.modified_at.min(), playlists.modified_at.max() # not quite sure what to do with this feature
# Out:
# (1310601600, 1509494400)

# %% [markdown]
# This feature describes the seconds since the last modification of the playlist. Because each measurement of seconds is rounded up to midnight of that day, we can convert seconds to days.
#
# _*It's helpful to consider once again that all playlists in the dataset were created between 2010 to 2017._

# %%
playlists.modified_at / (60 * 60 * 24) # / [(sec/min) x (min/hour) x (hour/day)]
# Out:
# 0      17129.0
# 1      17194.0
# 2      17003.0
# 3      17470.0
# 4      17217.0
#         ...
# 995    17452.0
# 996    17121.0
# 997    16323.0
# 998    17453.0
# 999    17451.0
# Name: modified_at, Length: 10000, dtype: float64

# %% [markdown]
# <font color='red'> This is only so helpful, for its hard to determine from the documentation the date from which these values began counting 😕 </font>

# %% [markdown]
# #### Playlist Descriptions

# %%
print(f"{100001 - playlists.description.isnull().sum()} non-null playlist descriptions")
# Out:
# 90197 non-null playlist descriptions

# %%
print(f"{playlists.description.nunique() - 1} unique descriptions")
# Out:
# 195 unique descriptions

# %%
# example of 10 playlist descriptions
list(playlists.description.unique()[1:11])
# Out:
# ['this playlist contains pretty much all my favorite songs and new songs I like.',
#  'My Rock&#x2F;Industrial Playlist is getting huge! Time to break it up. Grunge is here - includes Alice in Chains, Sound Garden, Pearl Jam. I&#x27;m throwing Alice In Chains new stuff in here too, just to keep it all together.',
#  'Es espanish musica.',
#  '[datains]=C-&#x2F;&#x2F;txt= This account has been hacked. Enjoy.',
#  'a sentimential longing or wistful affection for the past',
#  'songs for my sister',
#  'best time of year',
#  'Makes you feel good boi :)',
#  'none of these good times will ever last',
#  'Classic yet creative - folk house']

# %%
stop_words = ['as', 'the', 'and', 'that', 'our', 'my', 'they', 'in', 'on', 'of', 'that', 'this', 'or', 'are',
              'be', 'from', 'for', 'but', 'not', 'so', 'no', 'we', 'us', 'your', 'you', 'playlist', 'my', 'everything',
              'music', 'it', 'all', 'is', 'some', 'when', 'me', 'like', 'these', 'have', 'will', 'about', 'song', 'most',
              'to', 'get', 'with', 'out', 'at', 're', 'by', 'don', 'if', 'can', 'its', 'only', 'an', 'while', 'im',
              'dont', 'here', 'just', 'stuff', 've', 'quot', 'up', 'one', 'really', 'll', 'made', 'too', 'down', 'best',
              'listen', 'feel', 'songs', 'x27', 'x2f', 'a', 's', 'good', 'collection', 'year', 'what', 'vibe', 'great',
              'tune', 'I', 't', 'know', 'mix', 'u', 'want', 'keep', 'got', 'tunes', 'every', 'vibes', 'mostly', 'favorites',
              'listening', 'there', 'those', 'ever', 'm', 'favorite', 'who', 'time', 'something', 'has', 'D', 'more'
              'feeling', 'other', 'artist', 'life', 'mood', 'was', 'lt', 'R', 'lot', 'around', 'because', 'never', 'then',
              'than', 'track', 'listened', 'into', 'do', 'e', 'beat', 'them', 'way', 'through', 'self', 'take', 'more',
              'could', 'feelin', 'B', 'sound', 'thing', 'top', 'where', 'always', 'am', 'make', 'feeling', 'use',
              'he', 'how', 'P', 'things', 'wanted', 'fav', 'everyone']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_158/1798968878.py in <cell line: 19>()
#      17 # Create and generate a word cloud image:
#      18 unique_desc = playlists.description.unique()
# ---> 19 tokens_wc = WordCloud(stopwords=stop_words).generate(' '.join(list(unique_desc[1:200])))
#      20
#      21 # Display the generated image:
#
# NameError: name 'WordCloud' is not defined

# %%
# # stop_words = []
# desc_tokens = nltk.word_tokenize(unique_desc[1])
# cv = CountVectorizer(stop_words=stop_words, ngram_range=(1, 3))
# count_arr = cv.fit_transform(list(unique_desc[1:])).toarray()
# tokens = cv.get_feature_names_out()
# count_df = pd.DataFrame(data=count_arr, columns=tokens)
# # list(count_df.sum().sort_values(ascending=False).index[:100])

# %% [markdown]
# #### Playlist Names

# %% [markdown]
# Check lengths of playlist names, create horiz. bar chart to visualize (discrete numerical feature):

# %%
playlist_name_lengths = pd.Series([len(name.split()) for name in list(playlists.name) if name is not np.nan], name='Len. Playlist Names')
pnlvc = playlist_name_lengths.value_counts()
print(f"Mean playlist name length: {playlist_name_lengths.mean():.2f} words")
print(f"Min playlist name length: {playlist_name_lengths.min()} words")
print(f"Max playlist name length: {playlist_name_lengths.max()} words")

plt.figure(figsize=(18,5))
plt.barh(y=pnlvc.index, width=pnlvc.values)
plt.title('Distribution of Playlist Name Lengths (in words)')
plt.ylabel('Distribution Count')
plt.xlabel('Length (in words)')
plt.show()

# Print value counts to see values that are too small to see in the chart below
pnlvc
# Out:
# Mean playlist name length: 1.42 words
# Min playlist name length: 1 words
# Max playlist name length: 9 words
# 1    6592
# 2    2827
# 3     444
# 4      85
# 5      21
# 6      15
# 7       8
# 8       5
# 9       3
# Name: Len. Playlist Names, dtype: int64

# %% [markdown]
# Above we can see a word cloud of the top 200 tokens that appeared in all playlist names in the dataset, in which we can find:
#
# - Genres
#     - Rock
#     - Classic (Rock)
#     - Rap
#     - Indie
#     - Country
#     - Rock
#     - Pop
#     - Alternative
#     - Classical
#     - Soundtracks
# - Types of Sound
#     - Piano
#     - Acoustic
#     - Electro
#     - Jamz (rhythmic, upbeat)
#     - SLO, Slow (slow)
#     - Bangaz (energetic, upbeat)
#     - Groove (smooth)
# - Activities/Events
#     - Shower
#     - Wedding
#     - Party
#     - Running
#     - Workout
#     - Gym
#     - Beach
#     - Driving (Jeep, Car)
#     - Study
#     - Adventure
# - Time/Season/Era
#     - 2k17
#     - Weekend
#     - December
#     - Old
#     - New
#     - Throwbacks
# - Artists
#     - Justin (Bieber, Timberlake)
#     - Kodak (Black)
#     - Bruno, Mars (Bruno Mars)
#     - Jack (Harlow)
#     - Eyed (Black Eyed Peas)
#     - Cole (J. Cole)
# - Religious/Cultural
#     - Christmas
#     - Black
#     - Worship
# - Languages
#     - Spanish
# - Other
#     - Random
#     - Disney
#
# Perhaps even moreso with the palylist namse than with the playlist descriptions, we can see that there are many ways to describe a playlist mood. Again, this is important to understand as we look to develop our playlist generator, we will have to reverse engineer this relationship, **generating playlists that accurately reflect how different words and phrases (activities, events, genres, sounds, times, artists, etc.) impact the mood of a playlist**

# %% [markdown]
# #### Artist Names

# %%
# Most Frequent Artists
most_freq_artists = songs.artist_name.value_counts()
top_100 = most_freq_artists[:100][::-1]

# Plot Top 100 
plt.figure(figsize=(12, 18))
plt.barh(y=top_100.index, width=top_100.values)
plt.title('Top 100 Artists (by frequency across all playlists)\n*counted multiple times when appearing multiple times in a single playlist')
plt.xlabel('Appearances')
plt.ylabel('Artist Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# Above we can see the top 100 artists. Some insights:
#
# - People love Drake
# - R&B, Rap, and Pop are king
# - Country looks like a close fourth (Florida georgia Line, Thomas Rhett, Zac Brown Band)
# - Alternative/Indie is very much alive (Red Hot Chili Peppers, Twenty One Pilots, Fall Out Boy, Blink-182, Imagine Dragons, etc.)
# - People still listen to the Beatles, Queen, and the Rolling Stones

# %% [markdown]
# #### Song Names

# %%
# Most Frequent Songs
most_freq_songs = songs.track_name.value_counts()
top_100 = most_freq_songs[:100][::-1]

# Plot Top 100 
plt.figure(figsize=(12, 18))
plt.barh(y=top_100.index, width=top_100.values)
plt.title('Top 100 Songs (by frequency across all playlists)')
plt.xlabel('Appearances')
plt.ylabel('Song Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# Some insights:
#
# - Most popular song among all playlists: Closer by The Chainsmokers
# - R. Kelly's scandal seemed to have no impact on the popularity of his Ignition (Remix)
# - Once again we can see that Rap and Pop are king

# %% [markdown]
# #### Album Names

# %%
# Most Frequent Albums
most_freq_albums = songs.album_name.value_counts()
top_50 = most_freq_albums[:50][::-1]

# Plot Top 50
plt.figure(figsize=(12, 9))
plt.barh(y=top_50.index, width=top_50.values)
plt.title('Top 50 Album (by frequency across all playlists)\n*counted multiple times when appearing multiple times in a single playlist')
plt.xlabel('Appearances')
plt.ylabel('Album Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# Some insights:
# - Once, again, Rap/Hip-Hop, Pop, and R&B are king
#     - Views (Drake, Rap/Hip-Hop)
#     - Stoney (Post Malone, Pop/Hip-Hop)
#     - Greatest Hits (would have to go into data to find artist, could be referring to multiple artists)
#     - More Life (Drake, Rap/Hip-Hop)
#     - DAMN (Kendrick Lamar, Rap/Hip-Hop)
#     - American Teen (Khalid, Pop/R&B)
#     - Culture (Migos, Rap/Hip-Hop)
#     - Purpose (Justin Bieber, Pop)
#     - The Life of Pablo (Kanye West, Rap/Hip-Hop)
#
# - Once again, people love Drake (Views - Drake is number one album by a large margin)
# - Post Malone's Stoney, the 2nd most popular album across all playlists, was interestingly one of his first albums

# %% [markdown]
# #### Playlist Duration (Time to Listen Through)

# %%
print(f"Mean playlist duration: {playlists.duration_ms.mean() / (1000 * 60 * 60)} hours")
print(f"Std playlist duration: {playlists.duration_ms.std() / (1000 * 60 * 60)} hours")
print(f"Min playlist duration: {playlists.duration_ms.min() / (1000 * 60)} minutes")
print(f"Max playlist duration: {playlists.duration_ms.max() / (1000 * 60 * 60)} hours")
# Out:
# Mean playlist duration: 4.348111098388888 hours
# Std playlist duration: 3.5720190152999542 hours
# Min playlist duration: 12.276466666666666 minutes
# Max playlist duration: 23.08324027777778 hours

# %%
(playlists.duration_ms / (1000 * 60 * 60)).hist(bins=15)
plt.title('Distribution of Playlist Durations (hours)')
plt.xlabel('Duration (hours)')
plt.ylabel('Distribution Count')
plt.show()

# %%
# Filtered: Playlists with a duration less than 30 hours
duration_less_30_hrs = playlists['duration_ms'][playlists.duration_ms < 30 * 1000 * 60 * 60]
duration_less_30_hrs.hist(bins=15)
plt.title('Distribution of Playlist Durations (hours)\n*playlists less than 30 hours long')
plt.xlabel('Duration (hours)')
plt.ylabel('Distribution Count')
plt.show()

# %% [markdown]
# #### Followers of Playlist & Some Features Filtered by Most Followed

# %%
print(f"Mean playlist followers: {playlists.num_followers.mean()} followers")
print(f"Std playlist followers: {playlists.num_followers.std()} followers")
print(f"Min playlist followers: {playlists.num_followers.min()} follower")
print(f"Max playlist followers: {playlists.num_followers.max()} followers")
# Out:
# Mean playlist followers: 3.5183 followers
# Std playlist followers: 161.03646711066395 followers
# Min playlist followers: 1 follower
# Max playlist followers: 15842 followers

# %%
# (a) 100 Most Frequent artists among 500 MOST FOLLOWED playlists

# Get pid's of 500 MOST FOLLOWED Playlists
top_500_pid = playlists.sort_values('num_followers', ascending=False)['pid'][:500].values

# Extract df of songs in each playlist in above list of pid's (top_500_pid)
top_500_playlists = pd.concat([get_playlist(pid) for pid in top_500_pid], axis=0)

# Plot 100 most frequent artists among 500 most followed playlists
top100 = top_500_playlists.artist_name.value_counts()[:100][::-1]
plt.figure(figsize=(12, 18))
plt.barh(y=top100.index, width=top100.values)
plt.title('Top 100 Artists Among 500 Most Followed Playlists\n*counted multiple times when appearing multiple times in a single playlist')
plt.xlabel('Appearances')
plt.ylabel('Artist Name')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_158/1849219366.py:4: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   top_500_pid = playlists.sort_values('num_followers', ascending=False)['pid'][:500].values

# %%
import seaborn as sns

# %%
sns.heatmap(songs.corr())
plt.show()

plt.figure(figsize=(8,7))
sns.heatmap(playlists.corr())
plt.show()
# Out:
# /tmp/ipykernel_158/3638437396.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(songs.corr())
# /tmp/ipykernel_158/3638437396.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(playlists.corr())

# %% [markdown]
# - Most high correlations are rather meaningless, for they are completely intuitive (e.g. `duration_ms` and `num_tracks`)
# - Somehwat interesting insight: the more times a playlist is edited (`num_edits`), the longer it typically is (`duration_ms`). Somewhat intuitive, but not necessarily obvious.
# - No features highly correlated with `num_followers`, which is the only logical feature that could be considered as a target feature in experimenting with a linear regression or other kind of supervised learning model.

# %% [markdown]
# #### Other Features

# %%
playlists.collaborative.value_counts(normalize=True)
# Out:
# false    0.9781
# true     0.0219
# Name: collaborative, dtype: float64

# %% [markdown]
# Only 2.2% of playlists are collaborative, the rest are not.

# %% [markdown]
# SAVING DATAFRAMES AS CSV

# %%
playlists.to_csv('playlists.csv')

# %%
songs.to_csv('songs.csv')

# %% [markdown]
# ## Pre-processing Summary
#
# * Converted JSON data of 100,000 playlists to two foundational dataframes, containing data on 100,000 playlists and their songs
# * Also saved the data to csv for easier use.
